# %% [markdown]
# # LGM VIP 2021
# ##DATA ANALYTCS
# ###TASK 1 : Image to Pencil Sketch with Python
# **Author [Mrutyunjay Rout](https://www.linkedin.com/in/routmj7/)**
#
# **Task Description :**
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.
#
# Reference: https://thecleverprogrammer.com/2020/09/30/pencil-sketch-with-python

# %% [markdown]
# ###Importing required libraries

# %%
import cv2
#to display image
from IPython.display import Image 
from google.colab.patches import cv2_imshow

# %% [markdown]
# ###Loading image

# %%
from google.colab import files #to upload image
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9253fa47-f558-43da-b851-e3b99f8825d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9253fa47-f558-43da-b851-e3b99f8825d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Muskman.jpg to Muskman (3).jpg

# %%
img=cv2.imread("Muskman.jpg")  #Write the file name inside ().

# %% [markdown]
# ###Showing Image

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=483x346 at 0x7F3029D3AD90>

# %% [markdown]
# ###Image to Gray Scale

# %%
#converting to gray scale image
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#displaying converted image
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=483x346 at 0x7F3029D48490>

# %% [markdown]
# ###Gray scale to negative

# %%
#Using Bitwise Not operator 
#Converting image
img_neg=cv2.bitwise_not(img_gray)
#Displaying image
cv2_imshow(img_neg)
# Out:
# <PIL.Image.Image image mode=L size=483x346 at 0x7F302A597C50>

# %% [markdown]
# ###Negative to Blurred

# %%
#Converting Image
img_blur=cv2.GaussianBlur(img_neg,(21,21),0) #Smoothening using Gaussian Blur
#Displaying Image
cv2_imshow(img_blur)
# Out:
# <PIL.Image.Image image mode=L size=483x346 at 0x7F3029D48D50>

# %% [markdown]
# ###Mixing images for final pencil sketch output

# %%
def mixing(img_neg, img_blur):
  img_blur_inv=255-img_blur
  return cv2.divide(img_neg, img_blur_inv, scale=256.0)

sketch=mixing(img_gray, img_blur)

# %% [markdown]
# ###Final pencil sketch output

# %%
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=483x346 at 0x7F302A59B7D0>

# %% [markdown]
# ### Comparision Between original image and result sketch

# %%
cv2_imshow(img)
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=483x346 at 0x7F302A59B490>
# <PIL.Image.Image image mode=L size=483x346 at 0x7F302A59B650>
